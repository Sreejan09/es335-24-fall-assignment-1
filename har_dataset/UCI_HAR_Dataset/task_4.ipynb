# %%
import pandas as pd 
import numpy as np
import os
from sklearn.tree import DecisionTreeClassifier 
import matplotlib.pyplot as plt 
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
# ------------ QUESTION 1 --------------
# ------- model creation -------- 
from MakeDataset import X_train,y_train, X_test
from sklearn.preprocessing import MinMaxScaler

X_train_total_acc = np.sum(X_train**2, axis=2)
X_test_total_acc = np.sum(X_test**2, axis=2)

model = DecisionTreeClassifier()
model.fit(X_train_total_acc, y_train)

scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(X_train_total_acc)
model_with_normalized_feature = DecisionTreeClassifier()
model_with_normalized_feature.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
import pandas as pd
import os

ACTIVITIES = {
    1: 'WALKING',
    2: 'WALKING_UPSTAIRS',
    3: 'WALKING_DOWNSTAIRS',
    4: 'SITTING',
    5: 'STANDING',
    6: 'LAYING',
}

x_test_personal = []
y_test_personal = []

# Path to the main directory containing activity subfolders


for label, activity in ACTIVITIES.items():
    activity_folder = os.path.join('personal_data', activity)
    
    if os.path.exists(activity_folder):
        for filename in os.listdir(activity_folder):
            if filename.endswith('.csv'):
                file_path = os.path.join(activity_folder, filename)
                
                # Read 500 values from the 'aT' column, starting from offset 250
                data = pd.read_csv(file_path, skiprows=range(1, 250), nrows=500)
                data = data.iloc[:, -1:]
                data = data.T
                x_test_personal.append(data)
                y_test_personal.append(label)

# Concatenate all dataframes in x_test
x_test_personal = pd.concat(x_test_personal, ignore_index=True)

# Convert y_test to a pandas Series
y_test_personal = pd.Series(y_test_personal)

# Display the first few rows of x_test and y_test
print(x_test_personal.shape)
print(y_test_personal.shape)
# Out:
# (36, 500)
# (36,)

# %%
y_pred_personal = model.predict(x_test_personal)

# Calculate Accuracy
accuracy = accuracy_score(y_test_personal, y_pred_personal)
print(f"Accuracy: {accuracy:.2f}")

# Calculate Precision 
precision = precision_score(y_test_personal, y_pred_personal, average='weighted')
print(f"Precision : {precision:.2f}")

# Calculate Recall
recall = recall_score(y_test_personal, y_pred_personal, average='weighted')
print(f"Recall : {recall:.2f}")

# Confusion Matrix 
cm = confusion_matrix(y_test_personal, y_pred_personal)

print("Confusion Matrix")
print(cm)
# Out:
# Accuracy: 0.11
# Precision : 0.04
# Recall : 0.11
# Confusion Matrix
# [[4 1 0 0 0 1]
#  [6 0 0 0 0 0]
#  [5 1 0 0 0 0]
#  [0 0 6 0 0 0]
#  [0 0 6 0 0 0]
#  [0 0 6 0 0 0]]
# d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#  ---------- QUESTION 2 ----------

x_test_personal_scaled = scaler.transform(x_test_personal)
y_pred_personal = model_with_normalized_feature.predict(x_test_personal_scaled)


# Calculate Accuracy
accuracy = accuracy_score(y_test_personal, y_pred_personal)
print(f"Accuracy: {accuracy:.2f}")

# Calculate Precision 
precision = precision_score(y_test_personal, y_pred_personal, average='weighted')
print(f"Precision : {precision:.2f}")

# Calculate Recall
recall = recall_score(y_test_personal, y_pred_personal, average='weighted')
print(f"Recall : {recall:.2f}")

# Confusion Matrix 
cm = confusion_matrix(y_test_personal, y_pred_personal)

print("Confusion Matrix")
print(cm)
# Out:
# Accuracy: 0.14
# Precision : 0.10
# Recall : 0.14
# Confusion Matrix
# [[4 1 0 0 0 1]
#  [5 1 0 0 0 0]
#  [5 1 0 0 0 0]
#  [0 0 6 0 0 0]
#  [0 0 6 0 0 0]
#  [0 0 6 0 0 0]]
# d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### Question (iii)

# %%
import pandas as pd 
from langchain_groq.chat_models import ChatGroq

# %%
from config import API
# Groq API and Models 
Groq_Token = API  # Do not share this key with anyone

groq_models = {"llama3-70b": "llama3-70b-8192", "mixtral": "mixtral-8x7b-32768", "gemma-7b": "gemma-7b-it","llama3.1-70b":"llama-3.1-70b-versatile","llama3-8b":"llama3-8b-8192","llama3.1-8b":"llama-3.1-8b-instant","gemma-9b":"gemma2-9b-it"}

# %%
# using raw accelerometer data
from MakeDataset import X_train,X_test,y_train,y_test

X_train_total_acc = np.sum(X_train**2, axis=2)

# %%
Accelerometer_X_train = X_train_total_acc
Accelerometer_Y_train = y_train
Accelerometer_X_test = x_test_personal
Accelerometer_Y_test = y_test_personal

# %%
dictionary = {
    1 : "Walking",
    2 : "Walking upstairs",
    3 : "Walkimg downstairs",
    4 : "Sitting",
    5 : "Standing",
    6 : "Laying"
}

# %%
Acclerometer_examples = {
    "Laying" : [0.991],
    "Sitting" : [1.019],
    "Standing" : [1.063],
    "Walking" : [2.243],
    "Walking Downstairs" : [0.722],
    "Walking Upstairs" : [0.984] 
}

# %%
def few_shot(X,examples):
    df = pd.DataFrame(X)
    fewshot = []
    for index, row in df.head(500).iterrows():
        query = f"""

        I am providing you the accelerometer data as:

        {row}

        Here the activities can be as given in the dictionary:

        {dictionary}

        In the dictionary, an integer corresponding to the activities is provided. Use those integers to denote your response.

        Now, based on this accelerometer data and using the dictionary, tell me the type of activity that is performed.

        Here are few examples for you

        {examples}

        Use these examples and the values provided to find your prediction of the activity

        Don't give any explaination just print the answer, as integer
        """

        model_name = "gemma-7b"  # Choose the model
        llm = ChatGroq(model=groq_models[model_name], api_key=Groq_Token, temperature=0)
        answer = llm.invoke(query)

        fewshot.append(answer.content)
    
    print(fewshot)
    return fewshot

# %%
fewshot_response = few_shot(Accelerometer_X_test,Acclerometer_examples)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 fewshot_response = few_shot(Accelerometer_X_test,Acclerometer_examples)
#
# Cell In[45], line 30, in few_shot(X, examples)
#      28     model_name = "gemma-7b"  # Choose the model
#      29     llm = ChatGroq(model=groq_models[model_name], api_key=Groq_Token, temperature=0)
# ---> 30     answer = llm.invoke(query)
#      32     fewshot.append(answer.content)
#      34 print(fewshot)
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:276, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     265 def invoke(
#     266     self,
#     267     input: LanguageModelInput,
#    (...)
#     271     **kwargs: Any,
#     272 ) -> BaseMessage:
#     273     config = ensure_config(config)
#     274     return cast(
#     275         ChatGeneration,
# --> 276         self.generate_prompt(
#     277             [self._convert_input(input)],
#     278             stop=stop,
#     279             callbacks=config.get("callbacks"),
#     280             tags=config.get("tags"),
#     281             metadata=config.get("metadata"),
#     282             run_name=config.get("run_name"),
#     283             run_id=config.pop("run_id", None),
#     284             **kwargs,
#     285         ).generations[0][0],
#     286     ).message
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:776, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     768 def generate_prompt(
#     769     self,
#     770     prompts: List[PromptValue],
#    (...)
#     773     **kwargs: Any,
#     774 ) -> LLMResult:
#     775     prompt_messages = [p.to_messages() for p in prompts]
# --> 776     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     631         if run_managers:
#     632             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 633         raise e
#     634 flattened_outputs = [
#     635     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     636     for res in results
#     637 ]
#     638 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:623, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     620 for i, m in enumerate(messages):
#     621     try:
#     622         results.append(
# --> 623             self._generate_with_cache(
#     624                 m,
#     625                 stop=stop,
#     626                 run_manager=run_managers[i] if run_managers else None,
#     627                 **kwargs,
#     628             )
#     629         )
#     630     except BaseException as e:
#     631         if run_managers:
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_core\language_models\chat_models.py:845, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     843 else:
#     844     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 845         result = self._generate(
#     846             messages, stop=stop, run_manager=run_manager, **kwargs
#     847         )
#     848     else:
#     849         result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\langchain_groq\chat_models.py:472, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     467 message_dicts, params = self._create_message_dicts(messages, stop)
#     468 params = {
#     469     **params,
#     470     **kwargs,
#     471 }
# --> 472 response = self.client.create(messages=message_dicts, **params)
#     473 return self._create_chat_result(response)
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\groq\resources\chat\completions.py:287, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     146 def create(
#     147     self,
#     148     *,
#    (...)
#     175     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     176 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     177     """
#     178     Creates a model response for the given chat conversation.
#     179
#    (...)
#     285       timeout: Override the client-level default timeout for this request, in seconds
#     286     """
# --> 287     return self._post(
#     288         "/openai/v1/chat/completions",
#     289         body=maybe_transform(
#     290             {
#     291                 "messages": messages,
#     292                 "model": model,
#     293                 "frequency_penalty": frequency_penalty,
#     294                 "function_call": function_call,
#     295                 "functions": functions,
#     296                 "logit_bias": logit_bias,
#     297                 "logprobs": logprobs,
#     298                 "max_tokens": max_tokens,
#     299                 "n": n,
#     300                 "parallel_tool_calls": parallel_tool_calls,
#     301                 "presence_penalty": presence_penalty,
#     302                 "response_format": response_format,
#     303                 "seed": seed,
#     304                 "stop": stop,
#     305                 "stream": stream,
#     306                 "temperature": temperature,
#     307                 "tool_choice": tool_choice,
#     308                 "tools": tools,
#     309                 "top_logprobs": top_logprobs,
#     310                 "top_p": top_p,
#     311                 "user": user,
#     312             },
#     313             completion_create_params.CompletionCreateParams,
#     314         ),
#     315         options=make_request_options(
#     316             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     317         ),
#     318         cast_to=ChatCompletion,
#     319         stream=stream or False,
#     320         stream_cls=Stream[ChatCompletionChunk],
#     321     )
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\groq\_base_client.py:1244, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1230 def post(
#    1231     self,
#    1232     path: str,
#    (...)
#    1239     stream_cls: type[_StreamT] | None = None,
#    1240 ) -> ResponseT | _StreamT:
#    1241     opts = FinalRequestOptions.construct(
#    1242         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1243     )
# -> 1244     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\groq\_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File d:\iitgn_study\ml_assignments\es335-24-fall-assignment-1\.venv\lib\site-packages\groq\_base_client.py:1039, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1036         err.response.read()
#    1038     log.debug("Re-raising status error")
# -> 1039     raise self._make_status_error_from_response(err.response) from None
#    1041 return self._process_response(
#    1042     cast_to=cast_to,
#    1043     options=options,
#    (...)
#    1047     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1048 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Organization has been restricted. Please reach out to support if you believe this was in error.', 'type': 'invalid_request_error', 'code': 'organization_restricted'}}
